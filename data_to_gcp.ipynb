# %%
from google.cloud import storage
import os
import pandas as pd

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'encoded-ensign-412700-4edae8855548.json'

# %%
df = pd.read_csv('Data/Pozos_Colombia.csv', sep = ';')
df
# Out:
#      Department                 Field               Latitude  \
# 0     ANTIOQUIA           PUERTO NARE           6126539139.0
# 1     ANTIOQUIA           PUERTO NARE           6126539139.0
# 2     ANTIOQUIA           PUERTO NARE           6126539139.0
# 3     ANTIOQUIA        PUERTO TRIUNFO           5954830151.0
# 4     ANTIOQUIA                 YONDO           6925159318.0
# ...         ...                   ...                    ...
# 8511   CASANARE                ZORZAL  5.709.829.800.837.060
# 8512      Cesar                   Zoe  5.709.829.800.837.060
# 8513   Casanare              Zopilote  5.709.829.800.837.060
# 8514  Antioquia  Ãrea Teca - Cocorna  5.709.829.800.837.060
# 8515       Meta                Ãpalo  5.709.829.800.837.060
#
#                    Longitude                  Geolocalization  \
# 0             -7.470.317.722  POINT (-7470317722 6.126539139)
# 1             -7.470.317.722  POINT (-7470317722 6.126539139)
# ...

# %%
client = storage.Client()
bucket = client.get_bucket('well_data')

# %%
bucket.blob('well_data.csv').upload_from_string(df.to_csv())
